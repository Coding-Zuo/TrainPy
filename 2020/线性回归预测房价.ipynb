# %% [markdown]
# ### 线性回归预测房价
# 任务:
# 1.以面积为输入变量建立单因子模型，评估模型表现，可赎回线性回归结果
# 2.建立多因子模型，评估模型表现

# %%
import pandas as pd
import numpy as np
data=pd.read_csv('usa_housing_price.csv')

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.317139                   7.009188
# 1       79248.64245             4.997100                   6.730821
# 2       61287.06718             5.134110                   8.512727
# 3       63345.24005             3.811764                   5.586729
# 4       59982.19723             5.959445                   7.839388
#
#    Area Population        size         Price
# 0      23086.80050  188.214212  1.059034e+06
# 1      40173.07217  160.042526  1.505891e+06
# 2      36882.15940  227.273544  1.058988e+06
# 3      34310.24283  164.816630  1.260617e+06
# 4      26354.10947  161.966659  6.309435e+05

# %%
from matplotlib import pyplot as plt
fig=plt.figure(figsize=(10,10))
fig1=plt.subplot(231)
plt.scatter(data.loc[:,'Avg. Area Income'],data.loc[:,'Price'])
plt.title('Price VS Income')

fig2=plt.subplot(232)
plt.scatter(data.loc[:,'Avg. Area House Age'],data.loc[:,'Price'])
plt.title('Price VS House Age')

fig3=plt.subplot(233)
plt.scatter(data.loc[:,'Avg. Area Number of Rooms'],data.loc[:,'Price'])
plt.title('Price VS Number of Rooms')

fig4=plt.subplot(234)
plt.scatter(data.loc[:,'Area Population'],data.loc[:,'Price'])
plt.title('Price VS Population')

fig4=plt.subplot(235)
plt.scatter(data.loc[:,'size'],data.loc[:,'Price'])
plt.title('Price VS size')
# Out:
# Text(0.5, 1.0, 'Price VS size')

# %%
X=data.loc[:,'size']
y=data.loc[:,'Price']

# %%
from sklearn.linear_model import LinearRegression
LR1=LinearRegression()
X=np.array(X).reshape(-1,1)
LR1.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict_1=LR1.predict(X)
y_predict_1
# Out:
# array([1276881.85636623, 1173363.58767144, 1420407.32457443, ...,
#        1097848.86467426, 1264502.88144558, 1131278.58816273])

# %%
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error1=mean_squared_error(y,y_predict_1)
r2_score_1=r2_score(y,y_predict_1)

# %%
r2_score_1
# Out:
# 0.1275031240418234

# %%
fig6=plt.figure(figsize=(8,5))
plt.scatter(X,y)
plt.plot(X,y_predict_1,'r')

# %%
X_multi=data.drop(['Price'],axis=1)

# %%
LR_multi=LinearRegression()
LR_multi.fit(X_multi,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict_multi=LR_multi.predict(X_multi)
mean_squared_error1=mean_squared_error(y,y_predict_multi)
r2_score_1=r2_score(y,y_predict_multi)

# %%
r2_score_1
# Out:
# 0.9180229195220739

# %%
fig7=plt.figure(figsize=(8,5))
plt.scatter(y,y_predict_multi)

# %%
fig8=plt.figure(figsize=(8,5))
plt.scatter(y,y_predict_1)

# %%
X_test=[65000,5,5,30000,200]
X_test=np.array(X_test).reshape(1,-1)
X_test
# Out:
# array([[65000,     5,     5, 30000,   200]])

# %%
y_test_predict=LR_multi.predict(X_test)

# %%
y_test_predict
# Out:
# array([817052.19516299])
